# %%
# !pip install ray==2.10.0
# !pip install autogluon.tabular
# !pip install -U ipywidgets

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_df = pd.read_csv('/kaggle/input/playground-series-s4e8/train.csv').drop('id', axis=1)
train_df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     e          8.80         f           s         u                    f
# 1     p          4.51         x           h         o                    f
# 2     e          6.94         f           s         b                    f
# 3     e          3.88         f           y         g                    f
# 4     e          5.85         x           l         w                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               a            c          w         4.51  ...        NaN
# 1               a            c          n         4.79  ...        NaN
# 2               x            c          w         6.85  ...        NaN
# 3               s          NaN          g         4.16  ...        NaN
# 4               d          NaN          w         3.37  ...        NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0          NaN          w       NaN        NaN        f         f
# 1            y          o       NaN        NaN        t         z
# 2            s          n       NaN        NaN        f         f
# 3          NaN          w       NaN        NaN        f         f
# 4          NaN          w       NaN        NaN        f         f
#
#   spore-print-color habitat season
# 0               NaN       d      a
# 1               NaN       d      w
# 2               NaN       l      w
# 3               NaN       d      u
# 4               NaN       g      a
#
# [5 rows x 21 columns]

# %%
test_df = pd.read_csv('/kaggle/input/playground-series-s4e8/test.csv').drop('id', axis=1)
test_df.head()
# Out:
#    cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0          8.64         x         NaN         n                    t
# 1          6.90         o           t         o                    f
# 2          2.00         b           g         n                    f
# 3          3.47         x           t         n                    f
# 4          6.17         x           h         y                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  stem-width stem-root  \
# 0             NaN          NaN          w        11.13       17.12         b
# 1             NaN            c          y         1.27       10.75       NaN
# 2             NaN            c          n         6.18        3.14       NaN
# 3               s            c          n         4.98        8.51       NaN
# 4               p          NaN          y         6.73       13.70       NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0          NaN          w         u          w        t         g
# 1          NaN          n       NaN        NaN        f         f
# 2          NaN          n       NaN        NaN        f         f
# 3          NaN          w       NaN          n        t         z
# 4          NaN          y       NaN          y        t       NaN
#
#   spore-print-color habitat season
# 0               NaN       d      a
# 1               NaN       d      a
# 2               NaN       d      s
# 3               NaN       d      u
# 4               NaN       d      u

# %%
predictor = TabularPredictor(label='class',
                            eval_metric='mcc',
                            problem_type='binary').fit(train_df,
                                                       presets='best_quality',
                                                        time_limit=3600*10,
                                                       verbosity=2,
                                                       excluded_model_types=['KNN'],
                                                       ag_args_fit={'num_gpus': 1}
                                                      )
results = predictor.fit_summary()
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20240817_051642"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.10.13
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP Thu Jun 27 20:43:36 UTC 2024
# CPU Count:          4
# Memory Avail:       29.00 GB / 31.36 GB (92.5%)
# Disk Space Avail:   19.50 GB / 19.52 GB (99.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9000s of the 36000s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-08-17 05:16:47,173	INFO worker.py:1752 -- Started a local Ray instance.
# 		Context path: "AutogluonModels/ag-20240817_051642/ds_sub_fit/sub_fit_ho"
# (_dystack pid=195) Running DyStack sub-fit ...
# (_dystack pid=195) Beginning AutoGluon training ... Time limit = 8995s
# (_dystack pid=195) AutoGluon will save models to "AutogluonModels/ag-20240817_051642/ds_sub_fit/sub_fit_ho"
# (_dystack pid=195) Train Data Rows:    2770617
# (_dystack pid=195) Train Data Columns: 20
# (_dystack pid=195) Label Column:       class
# (_dystack pid=195) Problem Type:       binary
# (_dystack pid=195) Preprocessing data ...
# (_dystack pid=195) Selected class <--> label mapping:  class 1 = p, class 0 = e
# (_dystack pid=195) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (p) vs negative (e) class.
# (_dystack pid=195) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=195) Using Feature Generators to preprocess the data ...
# (_dystack pid=195) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=195) 	Available Memory:                    29341.45 MB
# (_dystack pid=195) 	Train Data (Original)  Memory Usage: 2319.00 MB (7.9% of available memory)
# (_dystack pid=195) 	Warning: Data size prior to feature transformation consumes 7.9% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# (_dystack pid=195) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=195) 	Stage 1 Generators:
# (_dystack pid=195) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=195) 	Stage 2 Generators:
# (_dystack pid=195) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=195) 	Stage 3 Generators:
# (_dystack pid=195) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=195) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=195) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=195) 	Stage 4 Generators:
# (_dystack pid=195) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=195) 	Stage 5 Generators:
# (_dystack pid=195) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=195) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=195) 		('float', [])  :  3 | ['cap-diameter', 'stem-height', 'stem-width']
# (_dystack pid=195) 		('object', []) : 17 | ['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', ...]
# (_dystack pid=195) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=195) 		('category', []) : 17 | ['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', ...]
# (_dystack pid=195) 		('float', [])    :  3 | ['cap-diameter', 'stem-height', 'stem-width']
# (_dystack pid=195) 	40.0s = Fit runtime
# (_dystack pid=195) 	20 features in original data used to generate 20 features in processed data.
# (_dystack pid=195) 	Train Data (Processed) Memory Usage: 108.34 MB (0.4% of available memory)
# (_dystack pid=195) Data preprocessing and feature engineering runtime = 47.18s ...
# (_dystack pid=195) AutoGluon will gauge predictive performance using evaluation metric: 'mcc'
# (_dystack pid=195) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=195) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=195) User-specified model hyperparameters to be fit:
# (_dystack pid=195) {
# (_dystack pid=195) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=195) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=195) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=195) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=195) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=195) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=195) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=195) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=195) }
# (_dystack pid=195) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=195) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=195) Fitting 108 L1 models ...
# (_dystack pid=195) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 5963.39s of the 8947.31s of remaining time.
# (_dystack pid=195) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=3.21%)
# (_ray_fit pid=590) 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=590) 1 warning generated.
# (_ray_fit pid=589) 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=590) 1 warning generated. [repeated 58x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=589) [1000]	valid_set's binary_logloss: 0.0365728	valid_set's mcc: 0.984198
# (_ray_fit pid=589) [2000]	valid_set's binary_logloss: 0.0360659	valid_set's mcc: 0.984506 [repeated 2x across cluster]
# (_ray_fit pid=590) [3000]	valid_set's binary_logloss: 0.035406	valid_set's mcc: 0.98488 [repeated 2x across cluster]
# (_ray_fit pid=589) 	Ran out of time, early stopping on iteration 3915. Best iteration is:
# (_ray_fit pid=589) 	[3647]	valid_set's binary_logloss: 0.0359025	valid_set's mcc: 0.984634
# (_ray_fit pid=589) 1 warning generated. [repeated 7x across cluster]
# (_ray_fit pid=664) 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=590) 	Ran out of time, early stopping on iteration 3937. Best iteration is:
# (_ray_fit pid=590) 	[3543]	valid_set's binary_logloss: 0.0353759	valid_set's mcc: 0.984956
# (_ray_fit pid=699) 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=664) [1000]	valid_set's binary_logloss: 0.0363292	valid_set's mcc: 0.98443 [repeated 2x across cluster]
# (_ray_fit pid=699) [1000]	valid_set's binary_logloss: 0.0363829	valid_set's mcc: 0.984337
# (_ray_fit pid=664) [2000]	valid_set's binary_logloss: 0.0358444	valid_set's mcc: 0.984797
# (_ray_fit pid=699) [2000]	valid_set's binary_logloss: 0.035958	valid_set's mcc: 0.984611
# (_ray_fit pid=664) [3000]	valid_set's binary_logloss: 0.0357384	valid_set's mcc: 0.984885
# (_ray_fit pid=699) [3000]	valid_set's binary_logloss: 0.0358824	valid_set's mcc: 0.984622
# (_ray_fit pid=664) 	Ran out of time, early stopping on iteration 3990. Best iteration is:
# (_ray_fit pid=664) 	[3831]	valid_set's binary_logloss: 0.0357229	valid_set's mcc: 0.98496
# (_ray_fit pid=746) 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=787) 	Training S1F6 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=746) [1000]	valid_set's binary_logloss: 0.0370816	valid_set's mcc: 0.983918
# (_ray_fit pid=787) [1000]	valid_set's binary_logloss: 0.0361509	valid_set's mcc: 0.984549
# (_ray_fit pid=746) [2000]	valid_set's binary_logloss: 0.0365701	valid_set's mcc: 0.984198
# (_ray_fit pid=787) [2000]	valid_set's binary_logloss: 0.0357109	valid_set's mcc: 0.984863
# (_ray_fit pid=746) [3000]	valid_set's binary_logloss: 0.0364206	valid_set's mcc: 0.98429
# (_ray_fit pid=787) [3000]	valid_set's binary_logloss: 0.0355733	valid_set's mcc: 0.984916
# (_ray_fit pid=746) [4000]	valid_set's binary_logloss: 0.0363959	valid_set's mcc: 0.984279
# (_ray_fit pid=746) 	Ran out of time, early stopping on iteration 4018. Best iteration is:
# (_ray_fit pid=746) 	[3201]	valid_set's binary_logloss: 0.0364091	valid_set's mcc: 0.984314
# (_ray_fit pid=828) 	Training S1F7 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=787) 	Ran out of time, early stopping on iteration 3938. Best iteration is:
# (_ray_fit pid=787) 	[3890]	valid_set's binary_logloss: 0.0355447	valid_set's mcc: 0.984986
# (_ray_fit pid=869) 	Training S1F8 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=828) [1000]	valid_set's binary_logloss: 0.0373678	valid_set's mcc: 0.984197
# (_ray_fit pid=869) [1000]	valid_set's binary_logloss: 0.0365551	valid_set's mcc: 0.984501
# (_ray_fit pid=828) [2000]	valid_set's binary_logloss: 0.0369035	valid_set's mcc: 0.984507
# (_ray_fit pid=869) [2000]	valid_set's binary_logloss: 0.0361498	valid_set's mcc: 0.984687
# (_ray_fit pid=828) [3000]	valid_set's binary_logloss: 0.0367914	valid_set's mcc: 0.984565
# (_ray_fit pid=869) [3000]	valid_set's binary_logloss: 0.0360616	valid_set's mcc: 0.984833
# (_ray_fit pid=828) 	Ran out of time, early stopping on iteration 3987. Best iteration is:
# (_ray_fit pid=828) 	[3677]	valid_set's binary_logloss: 0.0367622	valid_set's mcc: 0.984617
# (_ray_fit pid=869) [4000]	valid_set's binary_logloss: 0.0360699	valid_set's mcc: 0.984856
# (_ray_fit pid=869) 	Ran out of time, early stopping on iteration 4001. Best iteration is:
# (_ray_fit pid=869) 	[3893]	valid_set's binary_logloss: 0.0360613	valid_set's mcc: 0.98488
# (_dystack pid=195) 	0.9848	 = Validation score   (mcc)
# (_dystack pid=195) 	5210.87s	 = Training   runtime
# (_dystack pid=195) 	1062.51s	 = Validation runtime
# (_dystack pid=195) Fitting model: LightGBM_BAG_L1 ... Training model for up to 607.19s of the 3591.11s of remaining time.
# (_dystack pid=195) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=3.24%)
# (_ray_fit pid=1145) 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1146) 	Ran out of time, early stopping on iteration 261. Best iteration is:
# (_ray_fit pid=1146) 	[261]	valid_set's binary_logloss: 0.0399525	valid_set's mcc: 0.982131
# (_ray_fit pid=1146) 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1220) 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1145) 	Ran out of time, early stopping on iteration 260. Best iteration is:
# (_ray_fit pid=1145) 	[258]	valid_set's binary_logloss: 0.0404489	valid_set's mcc: 0.982182
# (_ray_fit pid=1220) 	Ran out of time, early stopping on iteration 259. Best iteration is:
# (_ray_fit pid=1220) 	[259]	valid_set's binary_logloss: 0.0399968	valid_set's mcc: 0.982385
# (_ray_fit pid=1228) 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1303) 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1228) 	Ran out of time, early stopping on iteration 257. Best iteration is:
# (_ray_fit pid=1228) 	[255]	valid_set's binary_logloss: 0.040469	valid_set's mcc: 0.98205
# (_ray_fit pid=1303) 	Ran out of time, early stopping on iteration 261. Best iteration is:
# (_ray_fit pid=1303) 	[260]	valid_set's binary_logloss: 0.0409706	valid_set's mcc: 0.981705
# (_ray_fit pid=1311) 	Training S1F6 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1386) 	Training S1F7 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1311) 	Ran out of time, early stopping on iteration 258. Best iteration is:
# (_ray_fit pid=1311) 	[258]	valid_set's binary_logloss: 0.0403622	valid_set's mcc: 0.982046
# (_ray_fit pid=1386) 	Ran out of time, early stopping on iteration 257. Best iteration is:
# (_ray_fit pid=1386) 	[257]	valid_set's binary_logloss: 0.0412013	valid_set's mcc: 0.981513
# (_ray_fit pid=1418) 	Training S1F8 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_dystack pid=195) 	0.982	 = Validation score   (mcc)
# (_dystack pid=195) 	533.98s	 = Training   runtime
# (_dystack pid=195) 	79.7s	 = Validation runtime
# (_dystack pid=195) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 59.3s of the 3043.21s of remaining time.
# (_ray_fit pid=1418) 	Ran out of time, early stopping on iteration 258. Best iteration is:
# (_ray_fit pid=1418) 	[258]	valid_set's binary_logloss: 0.0401379	valid_set's mcc: 0.982249
# (_dystack pid=195) 	Warning: Model is expected to require 960.4s to train, which exceeds the maximum time limit of 59.3s, skipping model...
# (_dystack pid=195) 	Time limit exceeded... Skipping RandomForestGini_BAG_L1.
# (_dystack pid=195) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 45.33s of the 3029.24s of remaining time.
# (_dystack pid=195) 	Warning: Model is expected to require 1092.7s to train, which exceeds the maximum time limit of 45.3s, skipping model...
# (_dystack pid=195) 	Time limit exceeded... Skipping RandomForestEntr_BAG_L1.
# (_dystack pid=195) Fitting model: CatBoost_BAG_L1 ... Training model for up to 29.67s of the 3013.58s of remaining time.
# (_dystack pid=195) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=3.30%)
# (_ray_fit pid=1717) 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1717) 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# (_dystack pid=195) Failed to unpickle serialized exception
# (_dystack pid=195) Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 46, in from_ray_exception
# (_dystack pid=195)     return pickle.loads(ray_exception.serialized_exception)
# (_dystack pid=195) ModuleNotFoundError: No module named '_catboost'
# (_dystack pid=195)
# (_dystack pid=195) The above exception was the direct cause of the following exception:
# (_dystack pid=195)
# (_dystack pid=195) Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/serialization.py", line 404, in deserialize_objects
# (_dystack pid=195)     obj = self._deserialize_object(data, metadata, object_ref)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/serialization.py", line 293, in _deserialize_object
# (_dystack pid=195)     return RayError.from_bytes(obj)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 40, in from_bytes
# (_dystack pid=195)     return RayError.from_ray_exception(ray_exception)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 49, in from_ray_exception
# (_dystack pid=195)     raise RuntimeError(msg) from e
# (_dystack pid=195) RuntimeError: Failed to unpickle serialized exception
# (_dystack pid=195) 	Warning: Exception caused CatBoost_BAG_L1 to fail during training... Skipping this model.
# (_dystack pid=195) 		System error: Failed to unpickle serialized exception
# (_dystack pid=195) traceback: Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 46, in from_ray_exception
# (_dystack pid=195)     return pickle.loads(ray_exception.serialized_exception)
# (_dystack pid=195) ModuleNotFoundError: No module named '_catboost'
# (_dystack pid=195)
# (_dystack pid=195) The above exception was the direct cause of the following exception:
# (_dystack pid=195)
# (_dystack pid=195) Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/serialization.py", line 404, in deserialize_objects
# (_dystack pid=195)     obj = self._deserialize_object(data, metadata, object_ref)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/serialization.py", line 293, in _deserialize_object
# (_dystack pid=195)     return RayError.from_bytes(obj)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 40, in from_bytes
# (_dystack pid=195)     return RayError.from_ray_exception(ray_exception)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 49, in from_ray_exception
# (_dystack pid=195)     raise RuntimeError(msg) from e
# (_dystack pid=195) RuntimeError: Failed to unpickle serialized exception
# (_dystack pid=195)
# (_dystack pid=195) Detailed Traceback:
# (_dystack pid=195) Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1904, in _train_and_save
# (_dystack pid=195)     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/trainer/abstract_trainer.py", line 1844, in _train_single
# (_dystack pid=195)     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/abstract/abstract_model.py", line 856, in fit
# (_dystack pid=195)     out = self._fit(**kwargs)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py", line 165, in _fit
# (_dystack pid=195)     return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 288, in _fit
# (_dystack pid=195)     self._fit_folds(
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py", line 714, in _fit_folds
# (_dystack pid=195)     fold_fitting_strategy.after_all_folds_scheduled()
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 668, in after_all_folds_scheduled
# (_dystack pid=195)     self._run_parallel(X, y, X_pseudo, y_pseudo, model_base_ref, time_limit_fold, head_node_id)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 610, in _run_parallel
# (_dystack pid=195)     self._process_fold_results(finished, unfinished, fold_ctx)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 572, in _process_fold_results
# (_dystack pid=195)     raise processed_exception
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/autogluon/core/models/ensemble/fold_fitting_strategy.py", line 537, in _process_fold_results
# (_dystack pid=195)     fold_model, pred_proba, time_start_fit, time_end_fit, predict_time, predict_1_time, predict_n_size = self.ray.get(finished)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
# (_dystack pid=195)     return fn(*args, **kwargs)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
# (_dystack pid=195)     return func(*args, **kwargs)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
# (_dystack pid=195)     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/worker.py", line 866, in get_objects
# (_dystack pid=195)     raise value
# (_dystack pid=195) ray.exceptions.RaySystemError: System error: Failed to unpickle serialized exception
# (_dystack pid=195) traceback: Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 46, in from_ray_exception
# (_dystack pid=195)     return pickle.loads(ray_exception.serialized_exception)
# (_dystack pid=195) ModuleNotFoundError: No module named '_catboost'
# (_dystack pid=195)
# (_dystack pid=195) The above exception was the direct cause of the following exception:
# (_dystack pid=195)
# (_dystack pid=195) Traceback (most recent call last):
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/serialization.py", line 404, in deserialize_objects
# (_dystack pid=195)     obj = self._deserialize_object(data, metadata, object_ref)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/_private/serialization.py", line 293, in _deserialize_object
# (_dystack pid=195)     return RayError.from_bytes(obj)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 40, in from_bytes
# (_dystack pid=195)     return RayError.from_ray_exception(ray_exception)
# (_dystack pid=195)   File "/opt/conda/lib/python3.10/site-packages/ray/exceptions.py", line 49, in from_ray_exception
# (_dystack pid=195)     raise RuntimeError(msg) from e
# (_dystack pid=195) RuntimeError: Failed to unpickle serialized exception
# (_dystack pid=195)
# (_ray_fit pid=1718) 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=1718) 	Warning: CatBoost on GPU is experimental. If you encounter issues, use CPU for training CatBoost instead.
# (_dystack pid=195) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 3.3s of the 2987.22s of remaining time.
# (_dystack pid=195) 	Warning: Model is expected to require 608.8s to train, which exceeds the maximum time limit of 3.3s, skipping model...
# (_dystack pid=195) 	Time limit exceeded... Skipping ExtraTreesGini_BAG_L1.
# (_dystack pid=195) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=195) Fitting model: WeightedEnsemble_L2 ... Training model for up to 596.34s of the 2977.7s of remaining time.
# (_dystack pid=195) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=195) 	0.9848	 = Validation score   (mcc)
# (_dystack pid=195) 	6.91s	 = Training   runtime
# (_dystack pid=195) 	0.46s	 = Validation runtime
# (_dystack pid=195) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=195) Fitting 108 L2 models ...
# (_dystack pid=195) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2970.2s of the 2970.04s of remaining time.
# (_dystack pid=195) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=3.84%)
# (_ray_fit pid=2037) 	Training S1F2 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2036) [1000]	valid_set's binary_logloss: 0.0368099	valid_set's mcc: 0.984494
# (_ray_fit pid=2111) 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training. [repeated 2x across cluster]
# (_ray_fit pid=2036) 	Ran out of time, early stopping on iteration 1890. Best iteration is:
# (_ray_fit pid=2036) 	[1888]	valid_set's binary_logloss: 0.036674	valid_set's mcc: 0.984605
# (_ray_fit pid=2152) 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2111) [1000]	valid_set's binary_logloss: 0.036165	valid_set's mcc: 0.984408
# (_ray_fit pid=2111) 	Ran out of time, early stopping on iteration 1829. Best iteration is:
# (_ray_fit pid=2111) 	[1737]	valid_set's binary_logloss: 0.0360363	valid_set's mcc: 0.984588
# (_ray_fit pid=2152) [1000]	valid_set's binary_logloss: 0.036943	valid_set's mcc: 0.984327
# (_ray_fit pid=2194) 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2235) 	Training S1F6 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2194) [1000]	valid_set's binary_logloss: 0.036156	valid_set's mcc: 0.984811
# (_ray_fit pid=2235) [1000]	valid_set's binary_logloss: 0.0358915	valid_set's mcc: 0.984856
# (_ray_fit pid=2194) 	Ran out of time, early stopping on iteration 1876. Best iteration is:
# (_ray_fit pid=2194) 	[1558]	valid_set's binary_logloss: 0.0360354	valid_set's mcc: 0.984881
# (_ray_fit pid=2276) 	Training S1F7 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2235) 	Ran out of time, early stopping on iteration 1877. Best iteration is:
# (_ray_fit pid=2235) 	[1835]	valid_set's binary_logloss: 0.0357852	valid_set's mcc: 0.984955
# (_ray_fit pid=2317) 	Training S1F8 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2276) [1000]	valid_set's binary_logloss: 0.0364094	valid_set's mcc: 0.984552
# (_ray_fit pid=2317) [1000]	valid_set's binary_logloss: 0.0348972	valid_set's mcc: 0.984838
# (_ray_fit pid=2276) 	Ran out of time, early stopping on iteration 1904. Best iteration is:
# (_ray_fit pid=2276) 	[1825]	valid_set's binary_logloss: 0.0362863	valid_set's mcc: 0.984616
# (_ray_fit pid=2317) 	Ran out of time, early stopping on iteration 1852. Best iteration is:
# (_ray_fit pid=2317) 	[1775]	valid_set's binary_logloss: 0.0347764	valid_set's mcc: 0.985071
# (_dystack pid=195) 	0.9847	 = Validation score   (mcc)
# (_dystack pid=195) 	2469.41s	 = Training   runtime
# (_dystack pid=195) 	466.22s	 = Validation runtime
# (_dystack pid=195) Fitting model: LightGBM_BAG_L2 ... Training model for up to 433.19s of the 433.03s of remaining time.
# (_dystack pid=195) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=3.85%)
# (_ray_fit pid=2600) 	Training S1F1 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2675) 	Training S1F3 with GPU, note that this may negatively impact model quality compared to CPU training. [repeated 2x across cluster]
# (_ray_fit pid=2717) 	Training S1F4 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2758) 	Training S1F5 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_ray_fit pid=2840) 	Training S1F7 with GPU, note that this may negatively impact model quality compared to CPU training. [repeated 2x across cluster]
# (_ray_fit pid=2876) 	Training S1F8 with GPU, note that this may negatively impact model quality compared to CPU training.
# (_dystack pid=195) 	0.9846	 = Validation score   (mcc)
# (_dystack pid=195) 	133.83s	 = Training   runtime
# (_dystack pid=195) 	3.87s	 = Validation runtime
# (_dystack pid=195) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 293.8s of the 293.64s of remaining time.
# (_dystack pid=195) 	Warning: Reducing model 'n_estimators' from 300 -> 77 due to low time. Expected time usage reduced from 1132.2s -> 293.8s...
# (_dystack pid=195) 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 220.47s compared to 72.39s of available time.
# (_dystack pid=195) 	Time limit exceeded... Skipping RandomForestGini_BAG_L2.
# (_dystack pid=195) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -17.72s of remaining time.
# (_dystack pid=195) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=195) 	0.9848	 = Validation score   (mcc)
# (_dystack pid=195) 	12.55s	 = Training   runtime
# (_dystack pid=195) 	0.46s	 = Validation runtime
# (_dystack pid=195) AutoGluon training complete, total runtime = 9025.61s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 325.9 rows/s (346328 batch size)
# (_dystack pid=195) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240817_051642/ds_sub_fit/sub_fit_ho")
# (_dystack pid=195) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      LightGBM_BAG_L2       0.985118   0.984614         mcc      320.434155    1146.084407  5878.684297                 1.924827                3.872624         133.829984            2       True          5
# 1    LightGBMXT_BAG_L1       0.985107   0.984753         mcc      292.652029    1062.510727  5210.870179               292.652029             1062.510727        5210.870179            1       True          1
# 2  WeightedEnsemble_L2       0.985107   0.984753         mcc      292.656753    1062.969386  5217.779527                 0.004723                0.458659           6.909348            2       True          3
# 3  WeightedEnsemble_L3       0.985107   0.984753         mcc      292.657001    1062.969339  5223.419115                 0.004971                0.458612          12.548936            3       True          6
# 4    LightGBMXT_BAG_L2       0.985043   0.984716         mcc      448.284421    1608.435774  8214.265371               129.775093              466.223991        2469.411058            2       True          4
# 5      LightGBM_BAG_L1       0.982475   0.982033         mcc       25.857298      79.701056   533.984133                25.857298               79.701056         533.984133            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	9505s	 = DyStack   runtime |	26495s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 26495s
# AutoGluon will save models to "AutogluonModels/ag-20240817_051642"
# Train Data Rows:    3116945
# Train Data Columns: 20
# Label Column:       class
# Problem Type:       binary
# Preprocessing data ...
# Selected class <--> label mapping:  class 1 = p, class 0 = e
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (p) vs negative (e) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    30952.92 MB
# 	Train Data (Original)  Memory Usage: 2608.77 MB (8.4% of available memory)
# 	Warning: Data size prior to feature transformation consumes 8.4% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  :  3 | ['cap-diameter', 'stem-height', 'stem-width']
# 		('object', []) : 17 | ['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 17 | ['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', ...]
# 		('float', [])    :  3 | ['cap-diameter', 'stem-height', 'stem-width']
# 	33.9s = Fit runtime
# 	20 features in original data used to generate 20 features in processed data.
# 	Train Data (Processed) Memory Usage: 121.88 MB (0.4% of available memory)
# Data preprocessing and feature engineering runtime = 37.37s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'mcc'
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 17634.14s of the 26457.81s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=2.79%)
# 	0.9849	 = Validation score   (mcc)
# 	8408.14s	 = Training   runtime
# 	1408.79s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 9039.28s of the 17862.95s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=2.79%)
# 	0.9845	 = Validation score   (mcc)
# 	4711.51s	 = Training   runtime
# 	738.17s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 4230.59s of the 13054.26s of remaining time.
# 	0.9841	 = Validation score   (mcc)
# 	1086.54s	 = Training   runtime
# 	114.12s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 3027.39s of the 11851.06s of remaining time.
# 	0.9842	 = Validation score   (mcc)
# 	1131.77s	 = Training   runtime
# 	123.2s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1769.83s of the 10593.5s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=2.95%)
# 	0.7705	 = Validation score   (mcc)
# 	201.85s	 = Training   runtime
# 	1.46s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1562.56s of the 10386.23s of remaining time.
# 	0.9835	 = Validation score   (mcc)
# 	642.44s	 = Training   runtime
# 	115.71s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 801.8s of the 9625.47s of remaining time.
# 	Not enough time to generate out-of-fold predictions for model. Estimated time required was 586.8s compared to 377.14s of available time.
# 	Time limit exceeded... Skipping ExtraTreesEntr_BAG_L1.
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 135.86s of the 8959.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=4.97%)
# 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L1.
# 2024-08-17 12:47:42,723	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 117.05s of the 8940.72s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=4.03%)
# 	0.485	 = Validation score   (mcc)
# 	179.02s	 = Training   runtime
# 	20.41s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1763.41s of the 8754.85s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.273, 'RandomForestEntr_BAG_L1': 0.273, 'RandomForestGini_BAG_L1': 0.182, 'XGBoost_BAG_L1': 0.182, 'LightGBM_BAG_L1': 0.091}
# 	0.9849	 = Validation score   (mcc)
# 	21.21s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 108 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 8732.99s of the 8732.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=4.99%)
# 	0.9848	 = Validation score   (mcc)
# 	1148.48s	 = Training   runtime
# 	130.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 7557.97s of the 7557.65s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=5.00%)
# 	0.9848	 = Validation score   (mcc)
# 	213.29s	 = Training   runtime
# 	6.58s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 7337.12s of the 7336.81s of remaining time.
# 	0.985	 = Validation score   (mcc)
# 	1669.13s	 = Training   runtime
# 	109.43s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 5554.86s of the 5554.56s of remaining time.
# 	0.9849	 = Validation score   (mcc)
# 	2016.84s	 = Training   runtime
# 	125.69s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 3408.93s of the 3408.64s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=5.30%)
# 	0.9848	 = Validation score   (mcc)
# 	220.75s	 = Training   runtime
# 	1.36s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 3181.8s of the 3181.5s of remaining time.
# 	0.985	 = Validation score   (mcc)
# 	668.04s	 = Training   runtime
# 	107.74s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 2402.37s of the 2402.08s of remaining time.
# 	0.985	 = Validation score   (mcc)
# 	777.41s	 = Training   runtime
# 	113.31s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1508.33s of the 1508.04s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=8.81%)
# 	0.9849	 = Validation score   (mcc)
# 	862.33s	 = Training   runtime
# 	38.67s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 634.6s of the 634.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=6.76%)
# 	0.9849	 = Validation score   (mcc)
# 	221.65s	 = Training   runtime
# 	22.74s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 403.85s of the 403.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=4.74%)
# 	0.9848	 = Validation score   (mcc)
# 	314.56s	 = Training   runtime
# 	26.95s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 79.68s of the 79.37s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2.0 workers, per: cpus=1, gpus=1, memory=5.21%)
# 	0.9841	 = Validation score   (mcc)
# 	87.92s	 = Training   runtime
# 	2.79s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 873.3s of the -18.54s of remaining time.
# 	Ensemble Weights: {'ExtraTreesEntr_BAG_L2': 0.2, 'NeuralNetFastAI_BAG_L2': 0.2, 'RandomForestGini_BAG_L2': 0.133, 'RandomForestEntr_BAG_L2': 0.133, 'NeuralNetTorch_BAG_L2': 0.133, 'LightGBMLarge_BAG_L2': 0.133, 'XGBoost_BAG_L1': 0.067}
# 	0.985	 = Validation score   (mcc)
# 	55.86s	 = Training   runtime
# 	0.42s	 = Validation runtime
# AutoGluon training complete, total runtime = 26570.49s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 167.6 rows/s (389619 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20240817_051642")
# *** Summary of fit() ***
# Estimated performance of each model:
#                       model  score_val eval_metric  pred_time_val      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       WeightedEnsemble_L3   0.984991         mcc    2939.121167  22145.313564                0.417520          55.864211            3       True         20
# 1   RandomForestGini_BAG_L2   0.984965         mcc    2631.288702  18030.398024              109.429628        1669.130870            2       True         11
# 2     ExtraTreesEntr_BAG_L2   0.984956         mcc    2635.166399  17138.675040              113.307325         777.407887            2       True         15
# 3     ExtraTreesGini_BAG_L2   0.984951         mcc    2629.600229  17029.307302              107.741155         668.040149            2       True         14
# 4   RandomForestEntr_BAG_L2   0.984946         mcc    2647.553660  18378.104784              125.694587        2016.837630            2       True         12
# 5    NeuralNetFastAI_BAG_L2   0.984923         mcc    2560.532330  17223.594440               38.673256         862.327286            2       True         16
# 6            XGBoost_BAG_L2   0.984874         mcc    2544.603032  16582.920473               22.743958         221.653319            2       True         17
# 7         LightGBMXT_BAG_L1   0.984857         mcc    1408.793692   8408.139899             1408.793692        8408.139899            1       True          1
# 8       WeightedEnsemble_L2   0.984856         mcc    2405.134373  15538.184842                0.442161          21.210239            2       True          8
# 9     NeuralNetTorch_BAG_L2   0.984826         mcc    2548.806643  16675.824259               26.947569         314.557105            2       True         18
# 10          LightGBM_BAG_L2   0.984823         mcc    2528.436921  16574.559685                6.577847         213.292531            2       True         10
# 11        LightGBMXT_BAG_L2   0.984798         mcc    2651.952033  17509.743231              130.092959        1148.476078            2       True          9
# 12          CatBoost_BAG_L2   0.984758         mcc    2523.214427  16582.012922                1.355354         220.745768            2       True         13
# 13          LightGBM_BAG_L1   0.984467         mcc     738.173892   4711.512437              738.173892        4711.512437            1       True          2
# 14  RandomForestEntr_BAG_L1   0.984167         mcc     123.201049   1131.765905              123.201049        1131.765905            1       True          4
# 15  RandomForestGini_BAG_L1   0.984124         mcc     114.118171   1086.536909              114.118171        1086.536909            1       True          3
# 16     LightGBMLarge_BAG_L2   0.984077         mcc    2524.651282  16449.188574                2.792208          87.921421            2       True         19
# 17    ExtraTreesGini_BAG_L1   0.983457         mcc     115.711204    642.444970              115.711204         642.444970            1       True          6
# 18          CatBoost_BAG_L1   0.770451         mcc       1.455658    201.847580                1.455658         201.847580            1       True          5
# 19           XGBoost_BAG_L1   0.485010         mcc      20.405408    179.019453               20.405408         179.019453            1       True          7
# Number of models trained: 20
# Types of models trained:
# {'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', []) : 17 | ['cap-shape', 'cap-surface', 'cap-color', 'does-bruise-or-bleed', 'gill-attachment', ...]
# ('float', [])    :  3 | ['cap-diameter', 'stem-height', 'stem-width']
# Plot summary of models saved to file: AutogluonModels/ag-20240817_051642SummaryOfModels.html
# *** End of fit() summary ***

# %%
predictor.leaderboard()
# Out:
#                       model  score_val eval_metric  pred_time_val  \
# 0       WeightedEnsemble_L3   0.984991         mcc    2939.121167
# 1   RandomForestGini_BAG_L2   0.984965         mcc    2631.288702
# 2     ExtraTreesEntr_BAG_L2   0.984956         mcc    2635.166399
# 3     ExtraTreesGini_BAG_L2   0.984951         mcc    2629.600229
# 4   RandomForestEntr_BAG_L2   0.984946         mcc    2647.553660
# 5    NeuralNetFastAI_BAG_L2   0.984923         mcc    2560.532330
# 6            XGBoost_BAG_L2   0.984874         mcc    2544.603032
# 7         LightGBMXT_BAG_L1   0.984857         mcc    1408.793692
# 8       WeightedEnsemble_L2   0.984856         mcc    2405.134373
# 9     NeuralNetTorch_BAG_L2   0.984826         mcc    2548.806643
# 10          LightGBM_BAG_L2   0.984823         mcc    2528.436921
# 11        LightGBMXT_BAG_L2   0.984798         mcc    2651.952033
# 12          CatBoost_BAG_L2   0.984758         mcc    2523.214427
# 13          LightGBM_BAG_L1   0.984467         mcc     738.173892
# 14  RandomForestEntr_BAG_L1   0.984167         mcc     123.201049
# 15  RandomForestGini_BAG_L1   0.984124         mcc     114.118171
# 16     LightGBMLarge_BAG_L2   0.984077         mcc    2524.651282
# 17    ExtraTreesGini_BAG_L1   0.983457         mcc     115.711204
# 18          CatBoost_BAG_L1   0.770451         mcc       1.455658
# 19           XGBoost_BAG_L1   0.485010         mcc      20.405408
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   22145.313564                0.417520          55.864211            3
# 1   18030.398024              109.429628        1669.130870            2
# 2   17138.675040              113.307325         777.407887            2
# 3   17029.307302              107.741155         668.040149            2
# 4   18378.104784              125.694587        2016.837630            2
# 5   17223.594440               38.673256         862.327286            2
# 6   16582.920473               22.743958         221.653319            2
# 7    8408.139899             1408.793692        8408.139899            1
# 8   15538.184842                0.442161          21.210239            2
# 9   16675.824259               26.947569         314.557105            2
# 10  16574.559685                6.577847         213.292531            2
# 11  17509.743231              130.092959        1148.476078            2
# 12  16582.012922                1.355354         220.745768            2
# 13   4711.512437              738.173892        4711.512437            1
# 14   1131.765905              123.201049        1131.765905            1
# 15   1086.536909              114.118171        1086.536909            1
# 16  16449.188574                2.792208          87.921421            2
# 17    642.444970              115.711204         642.444970            1
# 18    201.847580                1.455658         201.847580            1
# 19    179.019453               20.405408         179.019453            1
#
#     can_infer  fit_order
# 0        True         20
# 1        True         11
# 2        True         15
# 3        True         14
# 4        True         12
# 5        True         16
# 6        True         17
# 7        True          1
# 8        True          8
# 9        True         18
# 10       True         10
# 11       True          9
# 12       True         13
# 13       True          2
# 14       True          4
# 15       True          3
# 16       True         19
# 17       True          6
# 18       True          5
# 19       True          7

# %%
y_pred = predictor.predict(test_df)

# %%
sub = pd.read_csv('/kaggle/input/playground-series-s4e8/sample_submission.csv')
sub['class'] = y_pred
sub.to_csv('submission.csv', index=False)
